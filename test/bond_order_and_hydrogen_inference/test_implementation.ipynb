# %%
import pysmt
from xbpy import rdutil
import numpy as np

# %%
from xbpy import correct_bond_orders, proximity_bond

# %%
#test_mol = next(rdutil.read_molecules("test_cases/Mureidomycin E PDB.pdb"))
test_mol = next(rdutil.read_molecules("test_cases/broken_mol.sdf"))
#test_mol = next(rdutil.read_molecules("test_cases/generic_substruct_match_test.pdb", proximityBonding=False))

# %%
result_mol = proximity_bond(test_mol)

# %%
test_mol.GetPropsAsDict()
# Out:
# {'meeko': '{"is_sidechain": [false], "free_energy": 5.97, "intermolecular_energy": 0.0, "internal_energy": -19.09, "cluster_size": 1, "cluster_id": 1, "rank_in_cluster": 1}',
#  'path': '../../1 Autodock Docking/mureidomycin_E_docking/Mureidomycin_E-65_5ckr_bs_docked.sdf'}

# %%
result_mol.GetPropsAsDict()
# Out:
# {'meeko': '{"is_sidechain": [false], "free_energy": 5.97, "intermolecular_energy": 0.0, "internal_energy": -19.09, "cluster_size": 1, "cluster_id": 1, "rank_in_cluster": 1}',
#  'path': '../../1 Autodock Docking/mureidomycin_E_docking/Mureidomycin_E-65_5ckr_bs_docked.sdf'}

# %%
result_mol

# %%
rdutil.write_molecules(result_mol, "test_cases/generic_substruct_match_test_corrected.sdf")
